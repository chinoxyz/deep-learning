# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
UNKWOWN_TAG = '<UNK>'
EOS_TAG = '<EOS>'
def encode(text, vocab):
    result = []
    for sentence in text.split('\n'):
        result.append([vocab.get(word, vocab[UNKWOWN_TAG]) for word in sentence.split(' ')])
    return result

def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_encoded = encode(source_text,source_vocab_to_int)
    target_encoded = [sentence + [target_vocab_to_int[EOS_TAG]] for sentence in encode(target_text,target_vocab_to_int)]
    return source_encoded, target_encoded

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# /home/jsanchezrodr/myprojects/udacity_deep_learning/env/lib/python3.4/site-packages/ipykernel/__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(tf.int32,[None,None], name='input')
    targets = tf.placeholder(tf.int32, [None,None], name='targets')
    
    source_sequence_length = tf.placeholder(tf.int32, [None], name='source_sequence_length')
    target_sequence_length = tf.placeholder(tf.int32, [None], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    
    lr = tf.placeholder(tf.float32, (), name='lr')
    keep_prob = tf.placeholder(tf.float32, (), name='keep_prob')
    
    return inputs, targets, lr, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
GO_TAG = '<GO>'
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    go_id = target_vocab_to_int[GO_TAG]
    start_tensor = tf.zeros([batch_size, 1], tf.int32) + go_id
    result = tf.concat([start_tensor, target_data],1)
    
    return result[:,:-1]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)


def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    embedded_sequence = tf.contrib.layers.embed_sequence(
        rnn_inputs, source_vocab_size,encoding_embedding_size,
        True, trainable=True
    )
    
    cell_list = [tf.contrib.rnn.LSTMCell(rnn_size) for _ in range(num_layers)]
    cell_stack = tf.contrib.rnn.DropoutWrapper(
        tf.contrib.rnn.MultiRNNCell(cell_list),
        output_keep_prob=keep_prob
    )
    
    output,state = tf.nn.dynamic_rnn(
        cell_stack,
        embedded_sequence,
        source_sequence_length,
        dtype=tf.float32
    )
    
    return output,state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    
    helper = tf.contrib.seq2seq.TrainingHelper(
        dec_embed_input,
        target_sequence_length
    )

    decoder = tf.contrib.seq2seq.BasicDecoder(
        dec_cell,
        helper,
        encoder_state,
        output_layer=output_layer
    )
    
    
    (final_outputs, final_state, final_sequence_lengths) = tf.contrib.seq2seq.dynamic_decode(
        decoder,
        maximum_iterations=max_summary_length
    )
    return final_outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(
        dec_embeddings,
        start_tokens=tf.tile([start_of_sequence_id], [batch_size]),
        end_token=end_of_sequence_id
    )

    decoder = tf.contrib.seq2seq.BasicDecoder(
        dec_cell,
        helper,
        encoder_state,
        output_layer=output_layer
    )
    
    
    (final_outputs, final_state, final_sequence_lengths) = tf.contrib.seq2seq.dynamic_decode(
        decoder,
        maximum_iterations=max_target_sequence_length
    )
    return final_outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
from tensorflow.python.layers.core import Dense

GO_TAG = '<EOS>'
EOS_TAG = '<EOS>'
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    dec_embed_input = tf.contrib.layers.embed_sequence(
        dec_input, target_vocab_size,
        decoding_embedding_size,
        True, trainable=True, scope='EmbeddingScope'
    )
    with tf.variable_scope('EmbeddingScope', reuse=True):
        embed_var = tf.get_variable('embeddings')
        
    
    cell_list = [tf.contrib.rnn.LSTMCell(rnn_size) for _ in range(num_layers)]
    dec_cell = tf.contrib.rnn.DropoutWrapper(
        tf.contrib.rnn.MultiRNNCell(cell_list),
        output_keep_prob=keep_prob
    )
    # Used Dense from the test file
    output_layer = Dense(target_vocab_size,
          kernel_initializer=tf.contrib.layers.xavier_initializer(),
          name='output_layer')
    
    decoding_layer_train_output = decoding_layer_train(
        encoder_state, dec_cell, dec_embed_input, target_sequence_length, 
        max_target_sequence_length, output_layer, keep_prob
    )
    
    start_of_sequence_id = target_vocab_to_int[GO_TAG]
    end_of_sequence_id = target_vocab_to_int[EOS_TAG]
    decoding_layer_infer_output = decoding_layer_infer(
        encoder_state, dec_cell, embed_var, start_of_sequence_id, 
        end_of_sequence_id, max_target_sequence_length, target_vocab_size, 
        output_layer, batch_size, keep_prob
    )
    
    
    return decoding_layer_train_output, decoding_layer_infer_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    enc_output,enc_state = encoding_layer(
        input_data, rnn_size, num_layers, keep_prob, 
        source_sequence_length, source_vocab_size, enc_embedding_size
    )
    dec_input = process_decoder_input(
        target_data, target_vocab_to_int, batch_size
    )
    training_dec_output, inf_dec_output = decoding_layer(
        dec_input, enc_state, target_sequence_length, 
        max_target_sentence_length, rnn_size, num_layers, 
        target_vocab_to_int, target_vocab_size, batch_size, 
        keep_prob, dec_embedding_size
    )
    
    return training_dec_output, inf_dec_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 13
decoding_embedding_size = 13
# Learning Rate
learning_rate = 1e-2
# Dropout Keep Probability
keep_probability = 1
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# /home/jsanchezrodr/myprojects/udacity_deep_learning/env/lib/python3.4/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.2918, Validation Accuracy: 0.3723, Loss: 3.3375
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3592, Validation Accuracy: 0.3949, Loss: 2.9112
# Epoch   0 Batch   30/538 - Train Accuracy: 0.3178, Validation Accuracy: 0.3770, Loss: 2.7793
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4167, Validation Accuracy: 0.4219, Loss: 2.2842
# Epoch   0 Batch   50/538 - Train Accuracy: 0.3408, Validation Accuracy: 0.3999, Loss: 2.0694
# Epoch   0 Batch   60/538 - Train Accuracy: 0.3936, Validation Accuracy: 0.4522, Loss: 1.7250
# Epoch   0 Batch   70/538 - Train Accuracy: 0.3715, Validation Accuracy: 0.4141, Loss: 1.3888
# Epoch   0 Batch   80/538 - Train Accuracy: 0.3598, Validation Accuracy: 0.4268, Loss: 1.2777
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4686, Validation Accuracy: 0.4895, Loss: 1.0809
# Epoch   0 Batch  100/538 - Train Accuracy: 0.4357, Validation Accuracy: 0.4877, Loss: 0.9895
# Epoch   0 Batch  110/538 - Train Accuracy: 0.4469, Validation Accuracy: 0.5016, Loss: 0.9652
# Epoch   0 Batch  120/538 - Train Accuracy: 0.4904, Validation Accuracy: 0.5428, Loss: 0.8541
# Epoch   0 Batch  130/538 - Train Accuracy: 0.5073, Validation Accuracy: 0.5312, Loss: 0.8049
# Epoch   0 Batch  140/538 - Train Accuracy: 0.4965, Validation Accuracy: 0.5524, Loss: 0.8573
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5641, Validation Accuracy: 0.5627, Loss: 0.7633
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5608, Validation Accuracy: 0.5680, Loss: 0.7036
# Epoch   0 Batch  170/538 - Train Accuracy: 0.5915, Validation Accuracy: 0.5767, Loss: 0.7180
# Epoch   0 Batch  180/538 - Train Accuracy: 0.6044, Validation Accuracy: 0.5765, Loss: 0.6841
# Epoch   0 Batch  190/538 - Train Accuracy: 0.5709, Validation Accuracy: 0.5744, Loss: 0.6785
# Epoch   0 Batch  200/538 - Train Accuracy: 0.5666, Validation Accuracy: 0.5765, Loss: 0.6634
# Epoch   0 Batch  210/538 - Train Accuracy: 0.5634, Validation Accuracy: 0.5838, Loss: 0.6477
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5299, Validation Accuracy: 0.5767, Loss: 0.6928
# Epoch   0 Batch  230/538 - Train Accuracy: 0.5525, Validation Accuracy: 0.5653, Loss: 0.6725
# Epoch   0 Batch  240/538 - Train Accuracy: 0.5635, Validation Accuracy: 0.5788, Loss: 0.6431
# Epoch   0 Batch  250/538 - Train Accuracy: 0.5857, Validation Accuracy: 0.6014, Loss: 0.6260
# Epoch   0 Batch  260/538 - Train Accuracy: 0.5854, Validation Accuracy: 0.6110, Loss: 0.5998
# Epoch   0 Batch  270/538 - Train Accuracy: 0.5875, Validation Accuracy: 0.6005, Loss: 0.6089
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6440, Validation Accuracy: 0.6122, Loss: 0.5683
# Epoch   0 Batch  290/538 - Train Accuracy: 0.5885, Validation Accuracy: 0.6250, Loss: 0.5731
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6336, Validation Accuracy: 0.6278, Loss: 0.5606
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6125, Validation Accuracy: 0.6209, Loss: 0.5655
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6291, Validation Accuracy: 0.6280, Loss: 0.5350
# Epoch   0 Batch  330/538 - Train Accuracy: 0.6222, Validation Accuracy: 0.6254, Loss: 0.5250
# Epoch   0 Batch  340/538 - Train Accuracy: 0.5754, Validation Accuracy: 0.6092, Loss: 0.5628
# Epoch   0 Batch  350/538 - Train Accuracy: 0.6423, Validation Accuracy: 0.6293, Loss: 0.5418
# Epoch   0 Batch  360/538 - Train Accuracy: 0.6273, Validation Accuracy: 0.6344, Loss: 0.5340
# Epoch   0 Batch  370/538 - Train Accuracy: 0.6213, Validation Accuracy: 0.6341, Loss: 0.5393
# Epoch   0 Batch  380/538 - Train Accuracy: 0.6234, Validation Accuracy: 0.6422, Loss: 0.5107
# Epoch   0 Batch  390/538 - Train Accuracy: 0.6561, Validation Accuracy: 0.6328, Loss: 0.5074
# Epoch   0 Batch  400/538 - Train Accuracy: 0.6300, Validation Accuracy: 0.6403, Loss: 0.4998
# Epoch   0 Batch  410/538 - Train Accuracy: 0.6223, Validation Accuracy: 0.6317, Loss: 0.5059
# Epoch   0 Batch  420/538 - Train Accuracy: 0.6434, Validation Accuracy: 0.6552, Loss: 0.4935
# Epoch   0 Batch  430/538 - Train Accuracy: 0.6523, Validation Accuracy: 0.6623, Loss: 0.4897
# Epoch   0 Batch  440/538 - Train Accuracy: 0.6350, Validation Accuracy: 0.6634, Loss: 0.4992
# Epoch   0 Batch  450/538 - Train Accuracy: 0.6553, Validation Accuracy: 0.6539, Loss: 0.4776
# Epoch   0 Batch  460/538 - Train Accuracy: 0.6321, Validation Accuracy: 0.6612, Loss: 0.4616
# Epoch   0 Batch  470/538 - Train Accuracy: 0.6724, Validation Accuracy: 0.6664, Loss: 0.4450
# Epoch   0 Batch  480/538 - Train Accuracy: 0.6708, Validation Accuracy: 0.6586, Loss: 0.4487
# Epoch   0 Batch  490/538 - Train Accuracy: 0.6514, Validation Accuracy: 0.6786, Loss: 0.4455
# Epoch   0 Batch  500/538 - Train Accuracy: 0.6832, Validation Accuracy: 0.6701, Loss: 0.3968
# Epoch   0 Batch  510/538 - Train Accuracy: 0.6711, Validation Accuracy: 0.6694, Loss: 0.4219
# Epoch   0 Batch  520/538 - Train Accuracy: 0.6643, Validation Accuracy: 0.6822, Loss: 0.4318
# Epoch   0 Batch  530/538 - Train Accuracy: 0.6643, Validation Accuracy: 0.6660, Loss: 0.4068
# Epoch   1 Batch   10/538 - Train Accuracy: 0.6564, Validation Accuracy: 0.6788, Loss: 0.4092
# Epoch   1 Batch   20/538 - Train Accuracy: 0.6758, Validation Accuracy: 0.6863, Loss: 0.3811
# Epoch   1 Batch   30/538 - Train Accuracy: 0.6730, Validation Accuracy: 0.7099, Loss: 0.3900
# Epoch   1 Batch   40/538 - Train Accuracy: 0.7356, Validation Accuracy: 0.7003, Loss: 0.3168
# Epoch   1 Batch   50/538 - Train Accuracy: 0.7090, Validation Accuracy: 0.7047, Loss: 0.3562
# Epoch   1 Batch   60/538 - Train Accuracy: 0.7066, Validation Accuracy: 0.7005, Loss: 0.3605
# Epoch   1 Batch   70/538 - Train Accuracy: 0.7068, Validation Accuracy: 0.6967, Loss: 0.3305
# Epoch   1 Batch   80/538 - Train Accuracy: 0.6867, Validation Accuracy: 0.6960, Loss: 0.3555
# Epoch   1 Batch   90/538 - Train Accuracy: 0.6895, Validation Accuracy: 0.7148, Loss: 0.3181
# Epoch   1 Batch  100/538 - Train Accuracy: 0.7012, Validation Accuracy: 0.7076, Loss: 0.3064
# Epoch   1 Batch  110/538 - Train Accuracy: 0.7244, Validation Accuracy: 0.7354, Loss: 0.3019
# Epoch   1 Batch  120/538 - Train Accuracy: 0.7326, Validation Accuracy: 0.7248, Loss: 0.2831
# Epoch   1 Batch  130/538 - Train Accuracy: 0.7147, Validation Accuracy: 0.7216, Loss: 0.2851
# Epoch   1 Batch  140/538 - Train Accuracy: 0.7033, Validation Accuracy: 0.7401, Loss: 0.3093
# Epoch   1 Batch  150/538 - Train Accuracy: 0.7441, Validation Accuracy: 0.7315, Loss: 0.2827
# Epoch   1 Batch  160/538 - Train Accuracy: 0.7342, Validation Accuracy: 0.7441, Loss: 0.2706
# Epoch   1 Batch  170/538 - Train Accuracy: 0.7463, Validation Accuracy: 0.7537, Loss: 0.2778
# Epoch   1 Batch  180/538 - Train Accuracy: 0.7677, Validation Accuracy: 0.7417, Loss: 0.2651
# Epoch   1 Batch  190/538 - Train Accuracy: 0.7314, Validation Accuracy: 0.7514, Loss: 0.2702
# Epoch   1 Batch  200/538 - Train Accuracy: 0.7580, Validation Accuracy: 0.7569, Loss: 0.2487
# Epoch   1 Batch  210/538 - Train Accuracy: 0.7236, Validation Accuracy: 0.7654, Loss: 0.2470
# Epoch   1 Batch  220/538 - Train Accuracy: 0.7355, Validation Accuracy: 0.7605, Loss: 0.2363
# Epoch   1 Batch  230/538 - Train Accuracy: 0.7555, Validation Accuracy: 0.7686, Loss: 0.2385
# Epoch   1 Batch  240/538 - Train Accuracy: 0.7545, Validation Accuracy: 0.7638, Loss: 0.2275
# Epoch   1 Batch  250/538 - Train Accuracy: 0.7809, Validation Accuracy: 0.7532, Loss: 0.2261
# Epoch   1 Batch  260/538 - Train Accuracy: 0.7468, Validation Accuracy: 0.7752, Loss: 0.2180
# Epoch   1 Batch  270/538 - Train Accuracy: 0.7537, Validation Accuracy: 0.7825, Loss: 0.2124
# Epoch   1 Batch  280/538 - Train Accuracy: 0.8047, Validation Accuracy: 0.7875, Loss: 0.1967
# Epoch   1 Batch  290/538 - Train Accuracy: 0.8020, Validation Accuracy: 0.7857, Loss: 0.1929
# Epoch   1 Batch  300/538 - Train Accuracy: 0.8013, Validation Accuracy: 0.8045, Loss: 0.1925
# Epoch   1 Batch  310/538 - Train Accuracy: 0.8209, Validation Accuracy: 0.7688, Loss: 0.1821
# Epoch   1 Batch  320/538 - Train Accuracy: 0.8105, Validation Accuracy: 0.8091, Loss: 0.1737
# Epoch   1 Batch  330/538 - Train Accuracy: 0.8233, Validation Accuracy: 0.8109, Loss: 0.1705
# Epoch   1 Batch  340/538 - Train Accuracy: 0.8094, Validation Accuracy: 0.8018, Loss: 0.1774
# Epoch   1 Batch  350/538 - Train Accuracy: 0.8480, Validation Accuracy: 0.8276, Loss: 0.1676
# Epoch   1 Batch  360/538 - Train Accuracy: 0.8178, Validation Accuracy: 0.8255, Loss: 0.1765
# Epoch   1 Batch  370/538 - Train Accuracy: 0.8219, Validation Accuracy: 0.8354, Loss: 0.1699
# Epoch   1 Batch  380/538 - Train Accuracy: 0.8211, Validation Accuracy: 0.8230, Loss: 0.1463
# Epoch   1 Batch  390/538 - Train Accuracy: 0.8657, Validation Accuracy: 0.8251, Loss: 0.1400
# Epoch   1 Batch  400/538 - Train Accuracy: 0.8378, Validation Accuracy: 0.8398, Loss: 0.1582
# Epoch   1 Batch  410/538 - Train Accuracy: 0.8379, Validation Accuracy: 0.8212, Loss: 0.1465
# Epoch   1 Batch  420/538 - Train Accuracy: 0.8740, Validation Accuracy: 0.8414, Loss: 0.1479
# Epoch   1 Batch  430/538 - Train Accuracy: 0.8523, Validation Accuracy: 0.8395, Loss: 0.1407
# Epoch   1 Batch  440/538 - Train Accuracy: 0.8510, Validation Accuracy: 0.8336, Loss: 0.1478
# Epoch   1 Batch  450/538 - Train Accuracy: 0.8436, Validation Accuracy: 0.8461, Loss: 0.1626
# Epoch   1 Batch  460/538 - Train Accuracy: 0.8519, Validation Accuracy: 0.8395, Loss: 0.1382
# Epoch   1 Batch  470/538 - Train Accuracy: 0.8650, Validation Accuracy: 0.8267, Loss: 0.1403
# Epoch   1 Batch  480/538 - Train Accuracy: 0.8531, Validation Accuracy: 0.8258, Loss: 0.1421
# Epoch   1 Batch  490/538 - Train Accuracy: 0.8687, Validation Accuracy: 0.8466, Loss: 0.1349
# Epoch   1 Batch  500/538 - Train Accuracy: 0.8862, Validation Accuracy: 0.8475, Loss: 0.1036
# Epoch   1 Batch  510/538 - Train Accuracy: 0.8748, Validation Accuracy: 0.8402, Loss: 0.1130
# Epoch   1 Batch  520/538 - Train Accuracy: 0.8832, Validation Accuracy: 0.8727, Loss: 0.1193
# Epoch   1 Batch  530/538 - Train Accuracy: 0.8568, Validation Accuracy: 0.8450, Loss: 0.1259
# Epoch   2 Batch   10/538 - Train Accuracy: 0.8822, Validation Accuracy: 0.8888, Loss: 0.1225
# Epoch   2 Batch   20/538 - Train Accuracy: 0.8910, Validation Accuracy: 0.8635, Loss: 0.1088
# Epoch   2 Batch   30/538 - Train Accuracy: 0.8561, Validation Accuracy: 0.8732, Loss: 0.1144
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9094, Validation Accuracy: 0.8825, Loss: 0.0840
# Epoch   2 Batch   50/538 - Train Accuracy: 0.8844, Validation Accuracy: 0.8739, Loss: 0.0996
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9092, Validation Accuracy: 0.8770, Loss: 0.0978
# Epoch   2 Batch   70/538 - Train Accuracy: 0.8917, Validation Accuracy: 0.8931, Loss: 0.0877
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9021, Validation Accuracy: 0.8830, Loss: 0.0932
# Epoch   2 Batch   90/538 - Train Accuracy: 0.8975, Validation Accuracy: 0.8954, Loss: 0.0902
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9162, Validation Accuracy: 0.8954, Loss: 0.0775
# Epoch   2 Batch  110/538 - Train Accuracy: 0.9025, Validation Accuracy: 0.8908, Loss: 0.0821
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9219, Validation Accuracy: 0.8952, Loss: 0.0674
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9137, Validation Accuracy: 0.8883, Loss: 0.0718
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9104, Validation Accuracy: 0.8888, Loss: 0.0915
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9027, Validation Accuracy: 0.8920, Loss: 0.0729
# Epoch   2 Batch  160/538 - Train Accuracy: 0.8971, Validation Accuracy: 0.8860, Loss: 0.0715
# Epoch   2 Batch  170/538 - Train Accuracy: 0.8863, Validation Accuracy: 0.8956, Loss: 0.0817
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9122, Validation Accuracy: 0.8748, Loss: 0.0819
# Epoch   2 Batch  190/538 - Train Accuracy: 0.8992, Validation Accuracy: 0.9082, Loss: 0.0888
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9135, Validation Accuracy: 0.9112, Loss: 0.0683
# Epoch   2 Batch  210/538 - Train Accuracy: 0.8992, Validation Accuracy: 0.8945, Loss: 0.0696
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9038, Validation Accuracy: 0.8968, Loss: 0.0697
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9047, Validation Accuracy: 0.9091, Loss: 0.0707
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9117, Validation Accuracy: 0.9018, Loss: 0.0688
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9273, Validation Accuracy: 0.9006, Loss: 0.0628
# Epoch   2 Batch  260/538 - Train Accuracy: 0.8655, Validation Accuracy: 0.8858, Loss: 0.0712
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9014, Validation Accuracy: 0.8983, Loss: 0.0638
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9241, Validation Accuracy: 0.8855, Loss: 0.0565
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9020, Validation Accuracy: 0.8812, Loss: 0.0660
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9237, Validation Accuracy: 0.8983, Loss: 0.0701
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9181, Loss: 0.0643
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9222, Validation Accuracy: 0.9197, Loss: 0.0551
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9360, Validation Accuracy: 0.9070, Loss: 0.0518
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9174, Validation Accuracy: 0.9027, Loss: 0.0594
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9343, Validation Accuracy: 0.9194, Loss: 0.0606
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9070, Validation Accuracy: 0.9309, Loss: 0.0566
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9248, Validation Accuracy: 0.9130, Loss: 0.0577
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9119, Validation Accuracy: 0.9189, Loss: 0.0497
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9247, Validation Accuracy: 0.9064, Loss: 0.0445
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9185, Validation Accuracy: 0.9229, Loss: 0.0595
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9141, Loss: 0.0589
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9230, Validation Accuracy: 0.9112, Loss: 0.0540
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9172, Validation Accuracy: 0.9228, Loss: 0.0497
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9291, Validation Accuracy: 0.9144, Loss: 0.0544
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9191, Validation Accuracy: 0.9261, Loss: 0.0639
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9193, Validation Accuracy: 0.9251, Loss: 0.0550
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9324, Loss: 0.0472
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9386, Validation Accuracy: 0.9290, Loss: 0.0465
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9336, Validation Accuracy: 0.9267, Loss: 0.0485
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9565, Validation Accuracy: 0.9139, Loss: 0.0358
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9313, Loss: 0.0450
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9359, Validation Accuracy: 0.9350, Loss: 0.0486
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9266, Validation Accuracy: 0.9309, Loss: 0.0581
# Epoch   3 Batch   10/538 - Train Accuracy: 0.9186, Validation Accuracy: 0.9158, Loss: 0.0583
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9230, Validation Accuracy: 0.9329, Loss: 0.0502
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9082, Validation Accuracy: 0.9105, Loss: 0.0542
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9114, Loss: 0.0396
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9304, Loss: 0.0475
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9307, Validation Accuracy: 0.9187, Loss: 0.0496
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9317, Validation Accuracy: 0.9221, Loss: 0.0423
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9357, Loss: 0.0423
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9323, Validation Accuracy: 0.9313, Loss: 0.0487
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9313, Validation Accuracy: 0.9398, Loss: 0.0366
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9420, Validation Accuracy: 0.9343, Loss: 0.0409
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9508, Validation Accuracy: 0.9158, Loss: 0.0319
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9405, Validation Accuracy: 0.9327, Loss: 0.0440
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9238, Validation Accuracy: 0.9281, Loss: 0.0589
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9308, Loss: 0.0392
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9129, Validation Accuracy: 0.9316, Loss: 0.0414
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9219, Validation Accuracy: 0.9226, Loss: 0.0458
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9394, Validation Accuracy: 0.9260, Loss: 0.0431
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9271, Validation Accuracy: 0.9228, Loss: 0.0531
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9233, Loss: 0.0454
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9249, Validation Accuracy: 0.9354, Loss: 0.0470
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9289, Validation Accuracy: 0.9118, Loss: 0.0459
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9379, Loss: 0.0404
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9398, Validation Accuracy: 0.9169, Loss: 0.0406
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9354, Validation Accuracy: 0.9023, Loss: 0.0464
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9124, Validation Accuracy: 0.9197, Loss: 0.0497
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9273, Validation Accuracy: 0.9141, Loss: 0.0401
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9206, Loss: 0.0334
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9531, Validation Accuracy: 0.9418, Loss: 0.0335
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9368, Validation Accuracy: 0.9242, Loss: 0.0414
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9423, Loss: 0.0411
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9327, Validation Accuracy: 0.9403, Loss: 0.0350
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9251, Loss: 0.0318
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9474, Loss: 0.0434
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9181, Loss: 0.0437
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9178, Validation Accuracy: 0.9347, Loss: 0.0372
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9525, Validation Accuracy: 0.9345, Loss: 0.0403
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9328, Validation Accuracy: 0.9439, Loss: 0.0385
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9477, Validation Accuracy: 0.9426, Loss: 0.0330
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9313, Loss: 0.0425
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9354, Loss: 0.0380
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9387, Validation Accuracy: 0.9224, Loss: 0.0421
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9400, Loss: 0.0372
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9479, Validation Accuracy: 0.9389, Loss: 0.0383
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9323, Validation Accuracy: 0.9284, Loss: 0.0502
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9343, Validation Accuracy: 0.9368, Loss: 0.0435
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9544, Validation Accuracy: 0.9279, Loss: 0.0366
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9511, Validation Accuracy: 0.9441, Loss: 0.0361
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9442, Validation Accuracy: 0.9400, Loss: 0.0382
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9402, Loss: 0.0291
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9494, Loss: 0.0363
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9521, Validation Accuracy: 0.9476, Loss: 0.0390
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9309, Validation Accuracy: 0.9453, Loss: 0.0444
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9441, Loss: 0.0438
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9412, Loss: 0.0363
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9264, Validation Accuracy: 0.9242, Loss: 0.0397
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9528, Validation Accuracy: 0.9501, Loss: 0.0287
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9449, Validation Accuracy: 0.9501, Loss: 0.0335
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9517, Loss: 0.0394
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9375, Loss: 0.0319
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9499, Loss: 0.0320
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9462, Validation Accuracy: 0.9405, Loss: 0.0362
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9405, Loss: 0.0305
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9377, Loss: 0.0407
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9352, Loss: 0.0265
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9427, Validation Accuracy: 0.9382, Loss: 0.0415
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9291, Validation Accuracy: 0.9288, Loss: 0.0484
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9473, Loss: 0.0306
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9429, Validation Accuracy: 0.9341, Loss: 0.0331
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9591, Validation Accuracy: 0.9379, Loss: 0.0327
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9369, Validation Accuracy: 0.9343, Loss: 0.0398
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9373, Loss: 0.0505
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9354, Loss: 0.0301
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9366, Loss: 0.0328
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9286, Validation Accuracy: 0.9430, Loss: 0.0397
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9529, Loss: 0.0345
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9465, Validation Accuracy: 0.9466, Loss: 0.0327
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9412, Loss: 0.0335
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9309, Loss: 0.0409
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9304, Loss: 0.0316
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9444, Loss: 0.0289
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9662, Validation Accuracy: 0.9382, Loss: 0.0282
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9464, Validation Accuracy: 0.9565, Loss: 0.0340
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9448, Loss: 0.0368
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9481, Validation Accuracy: 0.9492, Loss: 0.0278
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9567, Loss: 0.0259
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9482, Validation Accuracy: 0.9474, Loss: 0.0306
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9561, Validation Accuracy: 0.9506, Loss: 0.0357
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9510, Loss: 0.0283
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9387, Loss: 0.0295
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9453, Loss: 0.0270
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9451, Loss: 0.0294
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9516, Validation Accuracy: 0.9437, Loss: 0.0346
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9363, Loss: 0.0308
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9523, Validation Accuracy: 0.9446, Loss: 0.0356
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9324, Validation Accuracy: 0.9423, Loss: 0.0345
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9566, Validation Accuracy: 0.8979, Loss: 0.0381
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9209, Validation Accuracy: 0.9292, Loss: 0.0443
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9211, Validation Accuracy: 0.9352, Loss: 0.0381
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9391, Loss: 0.0317
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9477, Validation Accuracy: 0.9549, Loss: 0.0311
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9526, Loss: 0.0318
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9668, Validation Accuracy: 0.9380, Loss: 0.0220
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9526, Validation Accuracy: 0.9379, Loss: 0.0294
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9405, Loss: 0.0330
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9402, Validation Accuracy: 0.9622, Loss: 0.0340
# Epoch   5 Batch   10/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9464, Loss: 0.0360
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9503, Loss: 0.0298
# Epoch   5 Batch   30/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9435, Loss: 0.0307
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9510, Loss: 0.0246
# Epoch   5 Batch   50/538 - Train Accuracy: 0.9551, Validation Accuracy: 0.9451, Loss: 0.0245
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9393, Validation Accuracy: 0.9359, Loss: 0.0329
# Epoch   5 Batch   70/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9529, Loss: 0.0234
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9474, Loss: 0.0270
# Epoch   5 Batch   90/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9547, Loss: 0.0313
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9528, Loss: 0.0207
# Epoch   5 Batch  110/538 - Train Accuracy: 0.9590, Validation Accuracy: 0.9524, Loss: 0.0251
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9672, Validation Accuracy: 0.9446, Loss: 0.0179
# Epoch   5 Batch  130/538 - Train Accuracy: 0.9647, Validation Accuracy: 0.9425, Loss: 0.0295
# Epoch   5 Batch  140/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9437, Loss: 0.0388
# Epoch   5 Batch  150/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9435, Loss: 0.0238
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9476, Loss: 0.0268
# Epoch   5 Batch  170/538 - Train Accuracy: 0.9477, Validation Accuracy: 0.9345, Loss: 0.0275
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9469, Loss: 0.0294
# Epoch   5 Batch  190/538 - Train Accuracy: 0.9474, Validation Accuracy: 0.9471, Loss: 0.0370
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9373, Loss: 0.0224
# Epoch   5 Batch  210/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9526, Loss: 0.0280
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9434, Loss: 0.0288
# Epoch   5 Batch  230/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9613, Loss: 0.0272
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9605, Validation Accuracy: 0.9499, Loss: 0.0284
# Epoch   5 Batch  250/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9522, Loss: 0.0292
# Epoch   5 Batch  260/538 - Train Accuracy: 0.9462, Validation Accuracy: 0.9501, Loss: 0.0313
# Epoch   5 Batch  270/538 - Train Accuracy: 0.9543, Validation Accuracy: 0.9487, Loss: 0.0280
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9546, Validation Accuracy: 0.9419, Loss: 0.0246
# Epoch   5 Batch  290/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9414, Loss: 0.0243
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9586, Loss: 0.0318
# Epoch   5 Batch  310/538 - Train Accuracy: 0.9553, Validation Accuracy: 0.9517, Loss: 0.0330
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9588, Loss: 0.0239
# Epoch   5 Batch  330/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9540, Loss: 0.0234
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9408, Validation Accuracy: 0.9592, Loss: 0.0255
# Epoch   5 Batch  350/538 - Train Accuracy: 0.9712, Validation Accuracy: 0.9377, Loss: 0.0274
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9544, Loss: 0.0237
# Epoch   5 Batch  370/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9508, Loss: 0.0243
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9577, Loss: 0.0238
# Epoch   5 Batch  390/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9464, Loss: 0.0244
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9503, Loss: 0.0276
# Epoch   5 Batch  410/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9485, Loss: 0.0294
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9490, Loss: 0.0280
# Epoch   5 Batch  430/538 - Train Accuracy: 0.9437, Validation Accuracy: 0.9529, Loss: 0.0302
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9514, Validation Accuracy: 0.9499, Loss: 0.0308
# Epoch   5 Batch  450/538 - Train Accuracy: 0.9382, Validation Accuracy: 0.9517, Loss: 0.0371
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9431, Validation Accuracy: 0.9517, Loss: 0.0283
# Epoch   5 Batch  470/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9482, Loss: 0.0283
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9398, Loss: 0.0275
# Epoch   5 Batch  490/538 - Train Accuracy: 0.9535, Validation Accuracy: 0.9508, Loss: 0.0272
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9288, Loss: 0.0168
# Epoch   5 Batch  510/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9311, Loss: 0.0261
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9411, Loss: 0.0303
# Epoch   5 Batch  530/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9386, Loss: 0.0380
# Epoch   6 Batch   10/538 - Train Accuracy: 0.9471, Validation Accuracy: 0.9375, Loss: 0.0361
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9499, Loss: 0.0288
# Epoch   6 Batch   30/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9416, Loss: 0.0315
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9435, Loss: 0.0251
# Epoch   6 Batch   50/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9412, Loss: 0.0265
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9517, Loss: 0.0271
# Epoch   6 Batch   70/538 - Train Accuracy: 0.9481, Validation Accuracy: 0.9482, Loss: 0.0253
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9656, Validation Accuracy: 0.9556, Loss: 0.0258
# Epoch   6 Batch   90/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9574, Loss: 0.0296
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9582, Validation Accuracy: 0.9529, Loss: 0.0227
# Epoch   6 Batch  110/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9387, Loss: 0.0263
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9434, Loss: 0.0192
# Epoch   6 Batch  130/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9377, Loss: 0.0273
# Epoch   6 Batch  140/538 - Train Accuracy: 0.9521, Validation Accuracy: 0.9327, Loss: 0.0348
# Epoch   6 Batch  150/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9343, Loss: 0.0220
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9338, Validation Accuracy: 0.9244, Loss: 0.0275
# Epoch   6 Batch  170/538 - Train Accuracy: 0.9587, Validation Accuracy: 0.9423, Loss: 0.0245
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9541, Validation Accuracy: 0.9396, Loss: 0.0277
# Epoch   6 Batch  190/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9485, Loss: 0.0373
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9490, Loss: 0.0235
# Epoch   6 Batch  210/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9402, Loss: 0.0292
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9382, Loss: 0.0298
# Epoch   6 Batch  230/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9458, Loss: 0.0272
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9537, Loss: 0.0236
# Epoch   6 Batch  250/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9407, Loss: 0.0232
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9540, Loss: 0.0276
# Epoch   6 Batch  270/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9464, Loss: 0.0236
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9492, Loss: 0.0218
# Epoch   6 Batch  290/538 - Train Accuracy: 0.9645, Validation Accuracy: 0.9499, Loss: 0.0237
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9626, Validation Accuracy: 0.9570, Loss: 0.0290
# Epoch   6 Batch  310/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9398, Loss: 0.0339
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9391, Loss: 0.0241
# Epoch   6 Batch  330/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9583, Loss: 0.0263
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9437, Validation Accuracy: 0.9480, Loss: 0.0335
# Epoch   6 Batch  350/538 - Train Accuracy: 0.9554, Validation Accuracy: 0.9490, Loss: 0.0335
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9582, Validation Accuracy: 0.9553, Loss: 0.0253
# Epoch   6 Batch  370/538 - Train Accuracy: 0.9664, Validation Accuracy: 0.9437, Loss: 0.0284
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9674, Validation Accuracy: 0.9501, Loss: 0.0246
# Epoch   6 Batch  390/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9595, Loss: 0.0218
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9743, Validation Accuracy: 0.9506, Loss: 0.0272
# Epoch   6 Batch  410/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9329, Loss: 0.0245
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9578, Validation Accuracy: 0.9480, Loss: 0.0277
# Epoch   6 Batch  430/538 - Train Accuracy: 0.9475, Validation Accuracy: 0.9510, Loss: 0.0267
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9640, Loss: 0.0256
# Epoch   6 Batch  450/538 - Train Accuracy: 0.9403, Validation Accuracy: 0.9419, Loss: 0.0346
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9565, Validation Accuracy: 0.9451, Loss: 0.0281
# Epoch   6 Batch  470/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9574, Loss: 0.0264
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9673, Validation Accuracy: 0.9512, Loss: 0.0204
# Epoch   6 Batch  490/538 - Train Accuracy: 0.9550, Validation Accuracy: 0.9542, Loss: 0.0285
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9489, Loss: 0.0148
# Epoch   6 Batch  510/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9524, Loss: 0.0231
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9529, Loss: 0.0259
# Epoch   6 Batch  530/538 - Train Accuracy: 0.9512, Validation Accuracy: 0.9632, Loss: 0.0278
# Epoch   7 Batch   10/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9483, Loss: 0.0351
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9549, Loss: 0.0290
# Epoch   7 Batch   30/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9402, Loss: 0.0366
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9540, Loss: 0.0226
# Epoch   7 Batch   50/538 - Train Accuracy: 0.9633, Validation Accuracy: 0.9485, Loss: 0.0239
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9564, Validation Accuracy: 0.9590, Loss: 0.0278
# Epoch   7 Batch   70/538 - Train Accuracy: 0.9528, Validation Accuracy: 0.9469, Loss: 0.0239
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9526, Loss: 0.0224
# Epoch   7 Batch   90/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9448, Loss: 0.0301
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9740, Validation Accuracy: 0.9528, Loss: 0.0224
# Epoch   7 Batch  110/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9412, Loss: 0.0284
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9586, Loss: 0.0178
# Epoch   7 Batch  130/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9318, Loss: 0.0263
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9421, Loss: 0.0315
# Epoch   7 Batch  150/538 - Train Accuracy: 0.9799, Validation Accuracy: 0.9432, Loss: 0.0230
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9567, Validation Accuracy: 0.9434, Loss: 0.0227
# Epoch   7 Batch  170/538 - Train Accuracy: 0.9578, Validation Accuracy: 0.9471, Loss: 0.0269
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9528, Loss: 0.0252
# Epoch   7 Batch  190/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9469, Loss: 0.0315
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9386, Loss: 0.0186
# Epoch   7 Batch  210/538 - Train Accuracy: 0.9656, Validation Accuracy: 0.9515, Loss: 0.0270
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9544, Validation Accuracy: 0.9460, Loss: 0.0265
# Epoch   7 Batch  230/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9611, Loss: 0.0256
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9567, Loss: 0.0214
# Epoch   7 Batch  250/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9441, Loss: 0.0329
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9351, Validation Accuracy: 0.9457, Loss: 0.0358
# Epoch   7 Batch  270/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9487, Loss: 0.0250
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9473, Loss: 0.0209
# Epoch   7 Batch  290/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9457, Loss: 0.0218
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9630, Validation Accuracy: 0.9526, Loss: 0.0271
# Epoch   7 Batch  310/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9483, Loss: 0.0312
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9492, Loss: 0.0223
# Epoch   7 Batch  330/538 - Train Accuracy: 0.9812, Validation Accuracy: 0.9556, Loss: 0.0208
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9572, Loss: 0.0262
# Epoch   7 Batch  350/538 - Train Accuracy: 0.9634, Validation Accuracy: 0.9421, Loss: 0.0285
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9586, Loss: 0.0223
# Epoch   7 Batch  370/538 - Train Accuracy: 0.9605, Validation Accuracy: 0.9503, Loss: 0.0249
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9680, Validation Accuracy: 0.9512, Loss: 0.0253
# Epoch   7 Batch  390/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9442, Loss: 0.0211
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9594, Validation Accuracy: 0.9537, Loss: 0.0240
# Epoch   7 Batch  410/538 - Train Accuracy: 0.9672, Validation Accuracy: 0.9503, Loss: 0.0209
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9489, Loss: 0.0280
# Epoch   7 Batch  430/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9528, Loss: 0.0261
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9528, Loss: 0.0248
# Epoch   7 Batch  450/538 - Train Accuracy: 0.9397, Validation Accuracy: 0.9567, Loss: 0.0325
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9524, Loss: 0.0239
# Epoch   7 Batch  470/538 - Train Accuracy: 0.9548, Validation Accuracy: 0.9553, Loss: 0.0257
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9556, Loss: 0.0207
# Epoch   7 Batch  490/538 - Train Accuracy: 0.9671, Validation Accuracy: 0.9650, Loss: 0.0243
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9794, Validation Accuracy: 0.9611, Loss: 0.0176
# Epoch   7 Batch  510/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9547, Loss: 0.0213
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9664, Validation Accuracy: 0.9498, Loss: 0.0235
# Epoch   7 Batch  530/538 - Train Accuracy: 0.9543, Validation Accuracy: 0.9538, Loss: 0.0266
# Epoch   8 Batch   10/538 - Train Accuracy: 0.9453, Validation Accuracy: 0.9572, Loss: 0.0234
# Epoch   8 Batch   20/538 - Train Accuracy: 0.9628, Validation Accuracy: 0.9471, Loss: 0.0246
# Epoch   8 Batch   30/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9574, Loss: 0.0267
# Epoch   8 Batch   40/538 - Train Accuracy: 0.9616, Validation Accuracy: 0.9581, Loss: 0.0214
# Epoch   8 Batch   50/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9519, Loss: 0.0217
# Epoch   8 Batch   60/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9577, Loss: 0.0247
# Epoch   8 Batch   70/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9604, Loss: 0.0219
# Epoch   8 Batch   80/538 - Train Accuracy: 0.9674, Validation Accuracy: 0.9641, Loss: 0.0193
# Epoch   8 Batch   90/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9553, Loss: 0.0252
# Epoch   8 Batch  100/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9600, Loss: 0.0165
# Epoch   8 Batch  110/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9496, Loss: 0.0193
# Epoch   8 Batch  120/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9489, Loss: 0.0142
# Epoch   8 Batch  130/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9496, Loss: 0.0212
# Epoch   8 Batch  140/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9411, Loss: 0.0301
# Epoch   8 Batch  150/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9545, Loss: 0.0194
# Epoch   8 Batch  160/538 - Train Accuracy: 0.9550, Validation Accuracy: 0.9533, Loss: 0.0212
# Epoch   8 Batch  170/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9556, Loss: 0.0267
# Epoch   8 Batch  180/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9409, Loss: 0.0261
# Epoch   8 Batch  190/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9446, Loss: 0.0287
# Epoch   8 Batch  200/538 - Train Accuracy: 0.9645, Validation Accuracy: 0.9528, Loss: 0.0163
# Epoch   8 Batch  210/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9501, Loss: 0.0264
# Epoch   8 Batch  220/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9414, Loss: 0.0216
# Epoch   8 Batch  230/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9670, Loss: 0.0252
# Epoch   8 Batch  240/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9462, Loss: 0.0219
# Epoch   8 Batch  250/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9469, Loss: 0.0259
# Epoch   8 Batch  260/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9439, Loss: 0.0291
# Epoch   8 Batch  270/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9391, Loss: 0.0276
# Epoch   8 Batch  280/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9506, Loss: 0.0210
# Epoch   8 Batch  290/538 - Train Accuracy: 0.9830, Validation Accuracy: 0.9512, Loss: 0.0186
# Epoch   8 Batch  300/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9482, Loss: 0.0265
# Epoch   8 Batch  310/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9521, Loss: 0.0228
# Epoch   8 Batch  320/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9458, Loss: 0.0221
# Epoch   8 Batch  330/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9533, Loss: 0.0223
# Epoch   8 Batch  340/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9494, Loss: 0.0261
# Epoch   8 Batch  350/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9487, Loss: 0.0271
# Epoch   8 Batch  360/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9632, Loss: 0.0232
# Epoch   8 Batch  370/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9531, Loss: 0.0233
# Epoch   8 Batch  380/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9556, Loss: 0.0188
# Epoch   8 Batch  390/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9569, Loss: 0.0154
# Epoch   8 Batch  400/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9549, Loss: 0.0211
# Epoch   8 Batch  410/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9615, Loss: 0.0186
# Epoch   8 Batch  420/538 - Train Accuracy: 0.9656, Validation Accuracy: 0.9508, Loss: 0.0242
# Epoch   8 Batch  430/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9478, Loss: 0.0245
# Epoch   8 Batch  440/538 - Train Accuracy: 0.9566, Validation Accuracy: 0.9439, Loss: 0.0244
# Epoch   8 Batch  450/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9474, Loss: 0.0274
# Epoch   8 Batch  460/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9538, Loss: 0.0229
# Epoch   8 Batch  470/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9577, Loss: 0.0211
# Epoch   8 Batch  480/538 - Train Accuracy: 0.9665, Validation Accuracy: 0.9469, Loss: 0.0209
# Epoch   8 Batch  490/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9593, Loss: 0.0243
# Epoch   8 Batch  500/538 - Train Accuracy: 0.9847, Validation Accuracy: 0.9595, Loss: 0.0135
# Epoch   8 Batch  510/538 - Train Accuracy: 0.9710, Validation Accuracy: 0.9616, Loss: 0.0236
# Epoch   8 Batch  520/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9622, Loss: 0.0252
# Epoch   8 Batch  530/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9576, Loss: 0.0242
# Epoch   9 Batch   10/538 - Train Accuracy: 0.9512, Validation Accuracy: 0.9570, Loss: 0.0253
# Epoch   9 Batch   20/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9648, Loss: 0.0276
# Epoch   9 Batch   30/538 - Train Accuracy: 0.9545, Validation Accuracy: 0.9508, Loss: 0.0243
# Epoch   9 Batch   40/538 - Train Accuracy: 0.9755, Validation Accuracy: 0.9609, Loss: 0.0166
# Epoch   9 Batch   50/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9609, Loss: 0.0232
# Epoch   9 Batch   60/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9622, Loss: 0.0252
# Epoch   9 Batch   70/538 - Train Accuracy: 0.9732, Validation Accuracy: 0.9590, Loss: 0.0164
# Epoch   9 Batch   80/538 - Train Accuracy: 0.9668, Validation Accuracy: 0.9544, Loss: 0.0194
# Epoch   9 Batch   90/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9494, Loss: 0.0243
# Epoch   9 Batch  100/538 - Train Accuracy: 0.9766, Validation Accuracy: 0.9540, Loss: 0.0156
# Epoch   9 Batch  110/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9476, Loss: 0.0231
# Epoch   9 Batch  120/538 - Train Accuracy: 0.9750, Validation Accuracy: 0.9579, Loss: 0.0140
# Epoch   9 Batch  130/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9540, Loss: 0.0220
# Epoch   9 Batch  140/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9538, Loss: 0.0367
# Epoch   9 Batch  150/538 - Train Accuracy: 0.9744, Validation Accuracy: 0.9609, Loss: 0.0196
# Epoch   9 Batch  160/538 - Train Accuracy: 0.9516, Validation Accuracy: 0.9354, Loss: 0.0237
# Epoch   9 Batch  170/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9474, Loss: 0.0250
# Epoch   9 Batch  180/538 - Train Accuracy: 0.9554, Validation Accuracy: 0.9398, Loss: 0.0237
# Epoch   9 Batch  190/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9446, Loss: 0.0255
# Epoch   9 Batch  200/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9494, Loss: 0.0176
# Epoch   9 Batch  210/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9560, Loss: 0.0206
# Epoch   9 Batch  220/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9535, Loss: 0.0218
# Epoch   9 Batch  230/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9604, Loss: 0.0207
# Epoch   9 Batch  240/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9441, Loss: 0.0178
# Epoch   9 Batch  250/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9510, Loss: 0.0183
# Epoch   9 Batch  260/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9437, Loss: 0.0249
# Epoch   9 Batch  270/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9540, Loss: 0.0198
# Epoch   9 Batch  280/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9547, Loss: 0.0181
# Epoch   9 Batch  290/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9414, Loss: 0.0196
# Epoch   9 Batch  300/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9521, Loss: 0.0257
# Epoch   9 Batch  310/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9448, Loss: 0.0265
# Epoch   9 Batch  320/538 - Train Accuracy: 0.9714, Validation Accuracy: 0.9478, Loss: 0.0168
# Epoch   9 Batch  330/538 - Train Accuracy: 0.9801, Validation Accuracy: 0.9423, Loss: 0.0195
# Epoch   9 Batch  340/538 - Train Accuracy: 0.9627, Validation Accuracy: 0.9524, Loss: 0.0222
# Epoch   9 Batch  350/538 - Train Accuracy: 0.9630, Validation Accuracy: 0.9538, Loss: 0.0256
# Epoch   9 Batch  360/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9576, Loss: 0.0234
# Epoch   9 Batch  370/538 - Train Accuracy: 0.9664, Validation Accuracy: 0.9529, Loss: 0.0228
# Epoch   9 Batch  380/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9606, Loss: 0.0188
# Epoch   9 Batch  390/538 - Train Accuracy: 0.9708, Validation Accuracy: 0.9554, Loss: 0.0148
# Epoch   9 Batch  400/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9561, Loss: 0.0197
# Epoch   9 Batch  410/538 - Train Accuracy: 0.9736, Validation Accuracy: 0.9432, Loss: 0.0182
# Epoch   9 Batch  420/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9576, Loss: 0.0254
# Epoch   9 Batch  430/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9645, Loss: 0.0231
# Epoch   9 Batch  440/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9632, Loss: 0.0248
# Epoch   9 Batch  450/538 - Train Accuracy: 0.9429, Validation Accuracy: 0.9453, Loss: 0.0273
# Epoch   9 Batch  460/538 - Train Accuracy: 0.9608, Validation Accuracy: 0.9489, Loss: 0.0233
# Epoch   9 Batch  470/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9565, Loss: 0.0201
# Epoch   9 Batch  480/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9386, Loss: 0.0209
# Epoch   9 Batch  490/538 - Train Accuracy: 0.9667, Validation Accuracy: 0.9538, Loss: 0.0193
# Epoch   9 Batch  500/538 - Train Accuracy: 0.9787, Validation Accuracy: 0.9567, Loss: 0.0126
# Epoch   9 Batch  510/538 - Train Accuracy: 0.9728, Validation Accuracy: 0.9551, Loss: 0.0203
# Epoch   9 Batch  520/538 - Train Accuracy: 0.9605, Validation Accuracy: 0.9418, Loss: 0.0237
# Epoch   9 Batch  530/538 - Train Accuracy: 0.9525, Validation Accuracy: 0.9501, Loss: 0.0226
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
UNKWOWN_TAG = '<UNK>'

def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    
    result = [vocab_to_int.get(word, vocab_to_int[UNKWOWN_TAG]) for word in sentence.split(' ')]
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [36, 181, 114, 204, 148, 29, 186]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [225, 47, 20, 266, 9, 224, 161, 1]
#   French Words: il a vu une voiture rouge . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
